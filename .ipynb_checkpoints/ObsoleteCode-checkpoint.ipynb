# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name: Deztany Jackson
# * Student pace: self paced
# * Scheduled project review date/time: June 22, 2022
# * Instructor name: Claude Fried
# * Blog post URL: http://dmvinedata.com/blog/

# %% [markdown]
# ## Microsoft Movie Studio Analysis
#
# #### Authors: Deztany Jackson

# %% [markdown]
# ## Overview
#
# This analysis directs Microsoft's potential studio head with actional insights on their path forward into developing a movie studio. These recommendations are determined from insights from box office movie "Ratings" and depends on other attributes such as "Genre", "Directors" and "Movie Budget". The datasets given were filtered to analyse movies and their associated  with a minimum of a  "8/10" ("B") rating. The analysis goal was to extract patterns from some of the "best" movies.
#
# #RESULTS
# #RECOMMENDATIONS

# %% [markdown]
# ## Business Problem
#
# Microsoft sees all the big companies creating original video content and they want to get in on the fun. They have decided to create a new movie studio, but they don’t know anything about creating movies. You are charged with exploring what types of films are currently doing the best at the box office. You must then translate those findings into actionable insights that the head of Microsoft's new movie studio can use to help decide what type of films to create.
#
# Microsft is in competition with current major studios which have been in business for many years and already have a wealth of experience. The questions driving the analysis, support  Microsoft making choices based on direct data output from their  competition as well as  potential growth areas that may be overlooked. The analysis questions and main variable of success were chosen with the mindset, Microsoft is a major tech company that has influence and skillsets in other areas of tech.
#
# #They have areas other usecases that can exploit findings"Ratings" are the mainThe potential growth areas are asked with the context of knowing Microsoft's technical coverage that can exploi a  a wealth of experienc
#
# Ref: [Phase 1 Project Description](https://learning.flatironschool.com/courses/4963/pages/phase-1-project-description?module_item_id=370765), 2022

# %% [markdown]
# ## Data Understanding
#
# Box office related datasets (SQL and CSV) with the box office movie target "Rating" variable and associated independent  "Genre, Director and Budget" variable information  were taken from [IMBD](https://www.imdb.com/) and [the-numbers](https://www.the-numbers.com/).

# %%
#Import libraries

import pandas as pd
import numpy as np
import sqlite3
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Allows querying of dataframe with SQL
import pandasql as sqldf

# %%
#Lambda function to query datafram with SQL
pysqldf = lambda q: sqldf(q, globals())

# %%
#Connecting with databases
conn = sqlite3.connect('im.db')

# %%
#View the list of tables in the "IMDB" database

df = pd.read_sql("""
SELECT name
FROM sqlite_master 
WHERE type = 'table';""", conn)
df
# Out:
#             name
# 0   movie_basics
# 1      directors
# 2      known_for
# 3     movie_akas
# 4  movie_ratings
# 5        persons
# 6     principals
# 7        writers

# %% [markdown]
# ### IMBD Tables Used:
#
# #### - movie_basics
#     - The movie_basics dataset describes just over 146,000 movies with their associated genres, years.
# #### - movie_ratings
#     - The movie_ratings dataset describes 73,856 movie'saverage rating (from average ratings that range from "1" to "10") and the number of votes the average is calculated (ranging from "5" to "1.84 Mil").
# #### - directors
#      - The directors dataset describes 291,174 movies and their associated director's id.
#
# #### - persons
#     - The persons dataset describes 606,648 people and their associated movie related profession(s).

# %% [markdown]
# #### IMBD Table: movie_basics

# %%
#Looking at movie_basic table
q_basics = '''
SELECT
    *
FROM movie_basics;
'''
MovBasics_df = pd.read_sql(q_basics, conn)
#What does the dataset include?
MovBasics_df.head()
# Out:
#     movie_id                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
MovBasics_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   movie_id         146144 non-null  object
#  1   primary_title    146144 non-null  object
#  2   original_title   146123 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  114405 non-null  float64
#  5   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB

# %%
MovBasics_df["genres"].value_counts()
# Out:
# Documentary                   32185
# Drama                         21486
# Comedy                         9177
# Horror                         4372
# Comedy,Drama                   3519
#                               ...
# Adventure,Music,Mystery           1
# Documentary,Horror,Romance        1
# Sport,Thriller                    1
# Comedy,Sport,Western              1
# Adventure,History,War             1
# Name: genres, Length: 1085, dtype: int64

# %%
MovBasics_df.isna().sum()
# Out:
# movie_id               0
# primary_title          0
# original_title        21
# start_year             0
# runtime_minutes    31739
# genres              5408
# dtype: int64

# %%
#Looking to see if there are any duplicates
q_basics = '''
SELECT
    movie_id,
    start_year,
    primary_title,
    genres,
    COUNT(*) AS CNT
FROM movie_basics
GROUP BY movie_id
HAVING COUNT(*) > 1
ORDER BY movie_id;
'''

MovBasics_df = pd.read_sql(q_basics, conn)
#Displays if there are duplicate movies
MovBasics_df
# Out:
# Empty DataFrame
# Columns: [movie_id, start_year, primary_title, genres, CNT]
# Index: []

# %% [markdown]
# #### IMBD Table: movie_ratings

# %%
#Looking at movie_ratings table
q_basics = '''
SELECT
    *
FROM movie_ratings;'''

MovRatings_df = pd.read_sql(q_basics, conn)
MovRatings_df.head()
# Out:
#      movie_id  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
MovRatings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   movie_id       73856 non-null  object
#  1   averagerating  73856 non-null  float64
#  2   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB

# %%
MovRatings_df.describe()
# Out:
#        averagerating      numvotes
# count   73856.000000  7.385600e+04
# mean        6.332729  3.523662e+03
# std         1.474978  3.029402e+04
# min         1.000000  5.000000e+00
# 25%         5.500000  1.400000e+01
# 50%         6.500000  4.900000e+01
# 75%         7.400000  2.820000e+02
# max        10.000000  1.841066e+06

# %%
MovRatings_df.isna().sum()
# Out:
# movie_id         0
# averagerating    0
# numvotes         0
# dtype: int64

# %% [markdown]
# #### IMBD Table: directors

# %%
#Looking at directors table
q_basics = '''
SELECT
    *
FROM directors;'''

MovDirID_df = pd.read_sql(q_basics, conn)
MovDirID_df.head()
# Out:
#     movie_id  person_id
# 0  tt0285252  nm0899854
# 1  tt0462036  nm1940585
# 2  tt0835418  nm0151540
# 3  tt0835418  nm0151540
# 4  tt0878654  nm0089502

# %%
MovDirID_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 291174 entries, 0 to 291173
# Data columns (total 2 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   movie_id   291174 non-null  object
#  1   person_id  291174 non-null  object
# dtypes: object(2)
# memory usage: 4.4+ MB

# %%
MovDirID_df.describe()
# Out:
#          movie_id  person_id
# count      291174     291174
# unique     140417     109253
# top     tt4050462  nm6935209
# freq         3818        238

# %%
MovDirID_df.isna().sum()
# Out:
# movie_id     0
# person_id    0
# dtype: int64

# %% [markdown]
# #### IMBD Table: persons

# %%
#Looking at persons table
q_basics = '''
SELECT
    *
FROM persons;'''

MovDir_df = pd.read_sql(q_basics, conn)
MovDir_df.head()
# Out:
#    person_id       primary_name  birth_year  death_year  \
# 0  nm0061671  Mary Ellen Bauder         NaN         NaN
# 1  nm0061865       Joseph Bauer         NaN         NaN
# 2  nm0062070         Bruce Baum         NaN         NaN
# 3  nm0062195       Axel Baumann         NaN         NaN
# 4  nm0062798        Pete Baxter         NaN         NaN
#
#                                  primary_profession
# 0         miscellaneous,production_manager,producer
# 1        composer,music_department,sound_department
# 2                        miscellaneous,actor,writer
# 3  camera_department,cinematographer,art_department
# 4  production_designer,art_department,set_decorator

# %%
MovDir_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 606648 entries, 0 to 606647
# Data columns (total 5 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   person_id           606648 non-null  object
#  1   primary_name        606648 non-null  object
#  2   birth_year          82736 non-null   float64
#  3   death_year          6783 non-null    float64
#  4   primary_profession  555308 non-null  object
# dtypes: float64(2), object(3)
# memory usage: 23.1+ MB

# %%
MovDir_df["primary_name"].isna().sum()
# Out:
# 0

# %% [markdown]
# #### Budget CSV: movie_budgets
#     - This dataset describes the budget and gross from 5782 movies. The movie name values are the only link to joining the these values with other movie datasets.

# %%
#Import CSV to a dataframe
Bud_df = pd.read_csv('movie_budgets.csv')
Bud_df.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
#Note that the production_budget is a string and not a number
Bud_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %% [markdown]
# ## Data Preparation
# Describe and justify the process for preparing the data for analysis.

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# #### movie_basic, movie_ratings, directors, persons

# %% [markdown]
# ###  Data Merge and Clean:
# movie_basic and movie_ratings

# %%
#Joining movie_basics and ratings
qB1 = """
SELECT
    movie_id,
    start_year,
    primary_title,
    genres,
    averagerating,
    numvotes
FROM movie_basics
JOIN movie_ratings
    USING (movie_id)
GROUP BY movie_id
ORDER BY numvotes DESC, averagerating
;
"""
Genre_Ratings= pd.read_sql(qB1,conn)

# %%
movieG_df = pd.DataFrame(Genre_Ratings)
movieG_df.head()
# Out:
#     movie_id  start_year          primary_title                   genres  \
# 0  tt1375666        2010              Inception  Action,Adventure,Sci-Fi
# 1  tt1345836        2012  The Dark Knight Rises          Action,Thriller
# 2  tt0816692        2014           Interstellar   Adventure,Drama,Sci-Fi
# 3  tt1853728        2012       Django Unchained            Drama,Western
# 4  tt0848228        2012           The Avengers  Action,Adventure,Sci-Fi
#
#    averagerating  numvotes
# 0            8.8   1841066
# 1            8.4   1387769
# 2            8.6   1299334
# 3            8.4   1211405
# 4            8.1   1183655

# %% [markdown]
# [Ref: Split Values on Rows on Stackoverflow ](https://stackoverflow.com/questions/17116814/pandas-how-do-i-split-text-in-a-column-into-multiple-rows)

# %%
#Spliting the genres into sep rows by ","
s = movieG_df["genres"].str.split(",").apply(pd.Series, 1, dtype = pd.StringDtype()).stack()
s.index = s.index.droplevel(-1) # align index
s.name = "genres" #name to join on
s
# Out:
# 0             Action
# 0          Adventure
# 0             Sci-Fi
# 1             Action
# 1           Thriller
#             ...
# 73851          Drama
# 73852    Documentary
# 73853    Documentary
# 73854    Documentary
# 73855    Documentary
# Name: genres, Length: 128490, dtype: object

# %%
#delete old dataframe column with multiple values
del movieG_df["genres"]

# %%
#making it equal to the new dataframe
movieG1_df = movieG_df.join(s)
movieG1_df.head()
# Out:
#     movie_id  start_year          primary_title  averagerating  numvotes  \
# 0  tt1375666        2010              Inception            8.8   1841066
# 0  tt1375666        2010              Inception            8.8   1841066
# 0  tt1375666        2010              Inception            8.8   1841066
# 1  tt1345836        2012  The Dark Knight Rises            8.4   1387769
# 1  tt1345836        2012  The Dark Knight Rises            8.4   1387769
#
#       genres
# 0     Action
# 0  Adventure
# 0     Sci-Fi
# 1     Action
# 1   Thriller

# %% [markdown]
# #### Missing Values
# Drop missing values from dataframe.

# %% [markdown]
# Depending on the amount of missing data I will drop the missing rows or fill in.  If there is a negligent amount compared to the entire dataset, I will choose to drop the values.

# %%
#Determine if there are missing data 
movieG1_df["genres"].isna().sum()
# Out:
# 804

# %%
#Checking to see if any ratings values have missing data
movieG_df["averagerating"].isna().sum()
# Out:
# 0

# %%
#drop missing values 
movieG1_df = movieG1_df.dropna()

# %% [markdown]
# Check similar genre values to see if any  could be merged.

# %%
movieG1_df["genres"].unique()
# Out:
# array(['Action', 'Adventure', 'Sci-Fi', 'Thriller', 'Drama', 'Western',
#        'Biography', 'Crime', 'Mystery', 'Comedy', 'Fantasy', 'Family',
#        'Animation', 'Romance', 'Music', 'History', 'Horror', 'Sport',
#        'War', 'Musical', 'Documentary', 'News', 'Game-Show', 'Reality-TV',
#        'Adult', 'Short'], dtype=object)

# %%
#Checking genres values movies to see if they are compatible to be merged
genCat = movieG1_df.loc[(movieG1_df["genres"] == "Music") | (movieG1_df["genres"] == "Musical")]
genCat.head(50)
# Out:
#        movie_id  start_year                       primary_title  \
# 33    tt2582802        2014                            Whiplash
# 88    tt3783958        2016                          La La Land
# 141   tt1727824        2018                   Bohemian Rhapsody
# 184   tt1707386        2012                      Les Misérables
# 209   tt1981677        2012                       Pitch Perfect
# 218   tt1517451        2018                      A Star Is Born
# 230   tt2771200        2017                Beauty and the Beast
# 307   tt1485796        2017                The Greatest Showman
# 390   tt1226229        2010                Get Him to the Greek
# 473   tt2848292        2015                     Pitch Perfect 2
# 476   tt1980929        2013                         Begin Again
# 500   tt2042568        2013                 Inside Llewyn Davis
# 556   tt0475290        2016                       Hail, Caesar!
# 569   tt1355630        2014                           If I Stay
# 678   tt4062536        2015                          Green Room
# 703   tt6412452        2018        The Ballad of Buster Scruggs
# 778   tt1859650        2012                   To Rome with Love
# 811   tt1702443        2011      Justin Bieber: Never Say Never
# 813   tt1294226        2010                       The Last Song
# 817   tt3544112        2016                         Sing Street
# 847   tt1126591        2010                           Burlesque
# 847   tt1126591        2010                           Burlesque
# 859   tt1605717        2014                               Frank
# 863   tt1336608        2012                        Rock of Ages
# 912   tt3312830        2015                               Youth
# 942   tt6911608        2018         Mamma Mia! Here We Go Again
# 973   tt2125608        2012             Searching for Sugar Man
# 1027  tt1193631        2010                          Step Up 3D
# 1051  tt1800741        2012                  Step Up Revolution
# 1078  tt2268016        2015                      Magic Mike XXL
# 1099  tt3960412        2016  Popstar: Never Stop Never Stopping
# 1139  tt4765284        2017                     Pitch Perfect 3
# 1168  tt2870648        2015                                 Amy
# 1169  tt1017451        2010                        The Runaways
# 1176  tt1068242        2011                           Footloose
# 1322  tt2024519        2012         The Broken Circle Breakdown
# 1358  tt1839596        2011                            Rockstar
# 1358  tt1839596        2011                            Rockstar
# 1376  tt2178470        2013             Yeh Jawaani Hai Deewani
# 1394  tt6543652        2018                            Cold War
# 1426  tt3787590        2015                 We Are Your Friends
# 1430  tt0903657        2014                        Love & Mercy
# 1448  tt2461132        2014                      Happy New Year
# 1473  tt2626350        2014                      Step Up All In
# 1474  tt1742044        2014                         Jersey Boys
# 1489  tt0770802        2011                             Samsara
# 1605  tt9412098        2019                                Fyre
# 1647  tt2203308        2013                          Aashiqui 2
# 1647  tt2203308        2013                          Aashiqui 2
# 1652  tt8359848        2018                              Climax
#
#       averagerating  numvotes   genres
# 33              8.5    616916    Music
# 88              8.0    436070    Music
# 141             8.0    345466    Music
# 184             7.6    285971  Musical
# 209             7.2    256565    Music
# 218             7.8    249245    Music
# 230             7.2    238325  Musical
# 307             7.6    199663  Musical
# 390             6.4    161653    Music
# 473             6.4    130692    Music
# 476             7.4    129884    Music
# 500             7.5    123759    Music
# 556             6.3    111422    Music
# 569             6.8    107625    Music
# 678             7.0     90773    Music
# 703             7.3     87418  Musical
# 778             6.3     79381    Music
# 811             1.6     74978    Music
# 813             6.0     74914    Music
# 817             8.0     74651    Music
# 847             6.4     71021    Music
# 847             6.4     71021  Musical
# 859             7.0     70130    Music
# 863             5.9     69910  Musical
# 912             7.3     64418    Music
# 942             6.7     60355  Musical
# 973             8.2     58654    Music
# 1027            6.2     53081    Music
# 1051            6.5     51295    Music
# 1078            5.6     48497    Music
# 1099            6.7     47278    Music
# 1139            5.8     45127    Music
# 1168            7.8     43814    Music
# 1169            6.6     43792    Music
# 1176            5.9     43251    Music
# 1322            7.8     36462    Music
# 1358            7.7     34727    Music
# 1358            7.7     34727  Musical
# 1376            7.1     33971  Musical
# 1394            7.6     33392    Music
# 1426            6.2     32327    Music
# 1430            7.4     32238    Music
# 1448            5.1     31583    Music
# 1473            6.0     30420    Music
# 1474            6.8     30410    Music
# 1489            8.5     29725    Music
# 1605            7.3     25387    Music
# 1647            7.0     24497    Music
# 1647            7.0     24497  Musical
# 1652            7.2     24335    Music

# %%
# Rename values in genre to match
movieG1_df["genres"].replace("Musical","Music", inplace = True)

# %% [markdown]
# Checking the statistical measures of the number of votes. I want to consider the average ratings that were made from a certain amount of votes. The mean number will be considered.

# %%
#Check the mean amount of votes given. 
movieG1_df.describe()
# Out:
#           start_year  averagerating      numvotes
# count  128490.000000  128490.000000  1.284900e+05
# mean     2014.221021       6.302146  5.337769e+03
# std         2.579176       1.457744  3.808942e+04
# min      2010.000000       1.000000  5.000000e+00
# 25%      2012.000000       5.400000  1.600000e+01
# 50%      2014.000000       6.400000  6.600000e+01
# 75%      2016.000000       7.300000  4.290000e+02
# max      2019.000000      10.000000  1.841066e+06

# %% [markdown]
# ### Filter Ratings

# %% [markdown]
# Filter table by an averagerating with a minimum value of "8" and with a minimum numvotes with a minimum value of the mean (5337). Rationale:  The analysis goal was to extract patterns from some of the "best" movies. An 8/10 rating is equivalent to a "B" rating. Using the mean numvotes filters out a lot of lower outliers where a low number of votes produced high ratings. This allows the ratings used to be more credible.

# %%
#Filters future dataset for a certain averagerating and numvote values
g = movieG1_df.loc[(movieG1_df["averagerating"] >=8) & (movieG1_df["numvotes"] > movieG1_df["numvotes"].mean())]
g.head(25)
# Out:
#      movie_id  start_year                               primary_title  \
# 0   tt1375666        2010                                   Inception
# 0   tt1375666        2010                                   Inception
# 0   tt1375666        2010                                   Inception
# 1   tt1345836        2012                       The Dark Knight Rises
# 1   tt1345836        2012                       The Dark Knight Rises
# 2   tt0816692        2014                                Interstellar
# 2   tt0816692        2014                                Interstellar
# 2   tt0816692        2014                                Interstellar
# 3   tt1853728        2012                            Django Unchained
# 3   tt1853728        2012                            Django Unchained
# 4   tt0848228        2012                                The Avengers
# 4   tt0848228        2012                                The Avengers
# 4   tt0848228        2012                                The Avengers
# 5   tt0993846        2013                     The Wolf of Wall Street
# 5   tt0993846        2013                     The Wolf of Wall Street
# 5   tt0993846        2013                     The Wolf of Wall Street
# 6   tt1130884        2010                              Shutter Island
# 6   tt1130884        2010                              Shutter Island
# 7   tt2015381        2014                     Guardians of the Galaxy
# 7   tt2015381        2014                     Guardians of the Galaxy
# 7   tt2015381        2014                     Guardians of the Galaxy
# 8   tt1431045        2016                                    Deadpool
# 8   tt1431045        2016                                    Deadpool
# 8   tt1431045        2016                                    Deadpool
# 10  tt2488496        2015  Star Wars: Episode VII - The Force Awakens
#
#     averagerating  numvotes     genres
# 0             8.8   1841066     Action
# 0             8.8   1841066  Adventure
# 0             8.8   1841066     Sci-Fi
# 1             8.4   1387769     Action
# 1             8.4   1387769   Thriller
# 2             8.6   1299334  Adventure
# 2             8.6   1299334      Drama
# 2             8.6   1299334     Sci-Fi
# 3             8.4   1211405      Drama
# 3             8.4   1211405    Western
# 4             8.1   1183655     Action
# 4             8.1   1183655  Adventure
# 4             8.1   1183655     Sci-Fi
# 5             8.2   1035358  Biography
# 5             8.2   1035358      Crime
# 5             8.2   1035358      Drama
# 6             8.1   1005960    Mystery
# 6             8.1   1005960   Thriller
# 7             8.1    948394     Action
# 7             8.1    948394  Adventure
# 7             8.1    948394     Comedy
# 8             8.0    820847     Action
# 8             8.0    820847  Adventure
# 8             8.0    820847     Comedy
# 10            8.0    784780     Action

# %%
#View filtered data statisics with 
g.describe()
# Out:
#         start_year  averagerating      numvotes
# count   522.000000     522.000000  5.220000e+02
# mean   2014.348659       8.251533  1.818726e+05
# std       2.487027       0.285624  3.110069e+05
# min    2010.000000       8.000000  5.406000e+03
# 25%    2013.000000       8.100000  9.988000e+03
# 50%    2014.000000       8.200000  2.937300e+04
# 75%    2016.000000       8.300000  1.816010e+05
# max    2019.000000       9.700000  1.841066e+06

# %% [markdown]
# ## Data Modeling

# %% [markdown]
# ## Write How did you analyze or model the data?
# How did you iterate on your initial approach to make it better?
# Why are these choices appropriate given the data and the business problem?

# %% [markdown]
# ### Genres

# %%
#Create Plot
fig, genre_rating_ax = plt.subplots(ncols = 1, nrows = 1, figsize=(30, 30))

g.plot.scatter(x = "genres", y = "numvotes", c = "averagerating", fontsize = 12,  s = 100,  colormap = "rainbow",   ax= genre_rating_ax )
genre_rating_ax .set_yscale('log', subs = [2,3,4,5,6,8])

x = np.arange(10000, 1900000, 100000)
genre_rating_ax.set_yticks(x)

#Set titles
genre_rating_ax.set_title('Distribution of averagerating for genres', fontsize=30)
genre_rating_ax.set_ylabel('Number of Rating Votes', fontsize=20)
genre_rating_ax.set_xlabel('Movie Genres', fontsize=20)

#Save image in folder
fig.savefig("genre_ratings.png", dpi=150)
#plt.show()

# %%
#Count the number of movies each genre has with min a rating of "8" and min 5337 votes.

#Look at genres with high ratings and a large amount of votes - subjective but insightful
#Look at genres with not a lot of movies for potentia cases
mC ="""
SELECT
    genres,
    COUNT (movie_id) AS MCNT,
    averagerating,
    numvotes
FROM g
GROUP BY genres
ORDER BY  MCNT DESC;
"""
MovieCount = pysqldf(mC)
MovieCount

# %% [markdown]
# ### Director

# %%
#Create Plot
fig, genreDir_rating_ax = plt.subplots(ncols = 1, nrows = 1, figsize=(30, 30))

intDir.plot.scatter(x = "Director", y = "genres", c = "orange" , s = 100,  colormap = "rainbow",   ax= genreDir_rating_ax )
genreDir_rating_ax .set_yscale('log', subs = [2,3,4,5,6,8])

#ylimit =[]
x = np.arange(10000, 1900000, 100000)
genre_rating_ax.set_yticks(x)

#Set titles
genreDir_rating_ax.set_title('Directors Top Rated Genres', fontsize=30)
genreDir_rating_ax.set_ylabel('Number of Rating Votes', fontsize=20)
genreDir_rating_ax.set_xlabel('Movie Genres', fontsize=20)

#Save image in folder
fig.savefig("genre_ratings.png", dpi=150)
#plt.show()

# %% [markdown]
# ### Movie Direct - Prep Merge

# %%
#Joining of several tables to get movie and their director

qD = """
SELECT
    movie_id,
    primary_name AS Director
FROM movie_basics 
JOIN movie_ratings
    USING (movie_id)
JOIN directors
    USING (movie_id)
JOIN persons
    USING(person_id);
"""
Dir_Sql = pd.read_sql(qD,conn)

movieD2_df = pd.DataFrame(Dir_Sql)
movieD2_df
# Out:
#          movie_id             Director
# 0       tt0063540  Harnam Singh Rawail
# 1       tt0063540  Harnam Singh Rawail
# 2       tt0063540  Harnam Singh Rawail
# 3       tt0063540  Harnam Singh Rawail
# 4       tt0066787            Mani Kaul
# ...           ...                  ...
# 181382  tt9914642         Chris Jordan
# 181383  tt9914642         Chris Jordan
# 181384  tt9914942            Laura Jou
# 181385  tt9914942            Laura Jou
# 181386  tt9916160   Joost van der Wiel
#
# [181387 rows x 2 columns]

# %%
#Keep Table COUNT (movie_id) AS MCNT,
#Number of Directors in each genre with  preconditions
q = """
SELECT  
   movie_id,
   genres,
   COUNT (Director) AS DirCount
FROM g
JOIN movieD2_df
    USING (movie_id)
GROUP BY genres
ORDER BY DirCount DESC;
"""
GenDir = pysqldf(q)
GenDir
# Out:
#      movie_id       genres  DirCount
# 0   tt0816692        Drama       306
# 1   tt1375666       Action       199
# 2   tt1375666    Adventure       181
# 3   tt2015381       Comedy       142
# 4   tt0435761    Animation       107
# 5   tt0993846        Crime        87
# 6   tt0993846    Biography        86
# 7   tt1345836     Thriller        84
# 8   tt1645089  Documentary        77
# 9   tt1375666       Sci-Fi        63
# 10  tt1130884      Mystery        41
# 11  tt2582802        Music        36
# 12  tt2488496      Fantasy        31
# 13  tt1504320      History        25
# 14  tt1798709      Romance        20
# 15  tt3461252       Horror        17
# 16  tt1255953          War        12
# 17  tt1291584        Sport        11
# 18  tt5929776         News        10
# 19  tt2543472       Family         8
# 20  tt1853728      Western         1

# %%
#How many movies within the  top Genres does each director have?
from pandasql import sqldf
pysqldf = lambda q: sqldf(q, globals())

# %% [markdown]
# ## Director Questions:
#     -How many different type of genres does each director have?
#     -How many movies does each director have (with preconditions)
#     -How many different type of genres does each director have (with preconditions)
#     -Which genres does each director have

# %%
#How many movies does each director have? (with averagerating and numvote preconditions) 
q = """
SELECT 
    director,
    COUNT ( DISTINCT movie_id) AS Movie_Count,
    COUNT (DISTINCT  genres) AS Genre_Count
FROM g
JOIN movieD2_df
    USING (movie_id)   
GROUP BY director
ORDER BY Movie_Count DESC;
"""

intDir = pysqldf(q)
intDir
# Out:
#               Director  Movie_Count  Genre_Count
# 0      Martin Scorsese            3            7
# 1     Denis Villeneuve            3            5
# 2    Christopher Nolan            3            5
# 3          Zoya Akhtar            2            3
# 4              Sukumar            2            4
# ..                 ...          ...          ...
# 211     Advait Chandan            1            2
# 212      Adrian Molina            1            3
# 213        Aditya Dhar            1            3
# 214       Adesh Prasad            1            3
# 215    A.R. Murugadoss            1            2
#
# [216 rows x 3 columns]

# %%
#GOOD TABLE
#For direectors with more than 1 movie
#Which genres does each director have

q = """
SELECT 
    director,
    genres,
    COUNT ( DISTINCT movie_id) AS Movie_Count
FROM g
JOIN movieD2_df
    USING (movie_id)
GROUP BY director, genres
HAVING Movie_Count > 1
ORDER BY Movie_Count DESC 
;

"""

Dir = pysqldf(q)
Dir
# Out:
#               Director       genres  Movie_Count
# 0     Denis Villeneuve        Drama            3
# 1     Denis Villeneuve      Mystery            3
# 2         Alper Caglar        Drama            2
# 3         Anand Gandhi        Drama            2
# 4        Anthony Russo       Action            2
# 5        Anthony Russo    Adventure            2
# 6        Anthony Russo       Sci-Fi            2
# 7       Anurag Kashyap        Crime            2
# 8            Can Ulkay        Drama            2
# 9    Christopher Nolan       Action            2
# 10   Christopher Nolan    Adventure            2
# 11   Christopher Nolan       Sci-Fi            2
# 12     Damien Chazelle        Drama            2
# 13     Damien Chazelle        Music            2
# 14   Dragan Bjelogrlic    Adventure            2
# 15   Dragan Bjelogrlic       Comedy            2
# 16           Joe Russo       Action            2
# 17           Joe Russo    Adventure            2
# 18           Joe Russo       Sci-Fi            2
# 19  Joshua Oppenheimer  Documentary            2
# 20         Lee Unkrich    Adventure            2
# 21         Lee Unkrich    Animation            2
# 22         Lee Unkrich       Comedy            2
# 23     Martin Scorsese    Biography            2
# 24       Neeraj Pandey     Thriller            2
# 25   Nuri Bilge Ceylan        Drama            2
# 26   Quentin Tarantino        Drama            2
# 27      S.S. Rajamouli       Action            2
# 28      S.S. Rajamouli        Drama            2
# 29     Stephen Chbosky        Drama            2
# 30         Sujoy Ghosh      Mystery            2
# 31             Sukumar       Action            2
# 32         Zoya Akhtar        Drama            2

# %%
#Table for plotting Top 25 Directs more than 2 movies and genre by ratings

#ROUND (AVG(numvotes), 1) as Avg_Votes
    #ROUND (AVG(averagerating), 1) as Avg_Rat,
q = """
SELECT 
    director,
    movie_id,
    numvotes,
    ROUND (AVG(numvotes), 1) as Avg_Votes,
    averagerating,
    ROUND (AVG(averagerating), 1) as Avg_Rat,
    genres
FROM g
JOIN movieD2_df
    USING (movie_id)
GROUP BY  director, movie_id, genres
ORDER BY averagerating DESC
;

"""

Dir_df = pysqldf(q)
Dir_df
# Out:
#                    Director   movie_id  numvotes  Avg_Votes  averagerating  \
# 0         Quentin Tarantino  tt7131622      5600     5600.0            9.7
# 1         Quentin Tarantino  tt7131622      5600     5600.0            9.7
# 2    Bharatha Hettiarachchi  tt5963218      6509     6509.0            9.5
# 3    Bharatha Hettiarachchi  tt5963218      6509     6509.0            9.5
# 4          Chathra Weeraman  tt5963218      6509     6509.0            9.5
# ..                      ...        ...       ...        ...            ...
# 592             Yuriy Bykov  tt3560686      8617     8617.0            8.0
# 593             Yuriy Bykov  tt3560686      8617     8617.0            8.0
# 594             Çagan Irmak  tt2150209      7750     7750.0            8.0
# 595             Çagan Irmak  tt2150209      7750     7750.0            8.0
# 596             Çagan Irmak  tt2150209      7750     7750.0            8.0
#
#      Avg_Rat    genres
# 0        9.7    Comedy
# 1        9.7     Drama
# 2        9.5     Drama
# 3        9.5   History
# 4        9.5     Drama
# ..       ...       ...
# 592      8.0     Drama
# 593      8.0  Thriller
# 594      8.0    Comedy
# 595      8.0     Drama
# 596      8.0    Family
#
# [597 rows x 7 columns]

# %% [markdown]
# # Director Visual

# %%
Dir_df

# %%
#tHIS IS THE rating and directors joined...above 8 with minimum amount of votes

q = """
SELECT 
    g.movie_id,
    g.primary_title,
    g.genres,
    g.averagerating,
    g.numvotes,
    Director,
    COUNT (genres) AS CNTg,
    COUNT (DISTINCT movie_id) AS CNTm,
    COUNT (DISTINCT genres) AS CNTg,
    ROUND (AVG(g.averagerating), 1) as AvgRat_Dir
FROM g
JOIN movieD_df
    USING (movie_id)
GROUP BY director
ORDER BY AvgRat_Dir DESC, g.numvotes DESC, g.genres DESC
"""

intDir = pysqldf(q)
intDir
# Out:
#       movie_id                                 primary_title       genres  \
# 0    tt5963218                                 Aloko Udapadi        Drama
# 1    tt5963218                                 Aloko Udapadi        Drama
# 2    tt7738784                                       Peranbu        Drama
# 3    tt7738784                                       Peranbu        Drama
# 4    tt7738784                                       Peranbu        Drama
# ..         ...                                           ...          ...
# 211  tt2358913  Berserk: The Golden Age Arc III - The Advent       Action
# 212  tt5116410                                         Tower    Animation
# 213  tt4309356                                           Ivy        Drama
# 214  tt1698010                      TT3D: Closer to the Edge  Documentary
# 215  tt7765910               Aravindha Sametha Veera Raghava       Action
#
#      averagerating  numvotes                Director  CNTg  CNTm  CNTg  \
# 0              9.5      6509  Bharatha Hettiarachchi     2     1     2
# 1              9.5      6509        Chathra Weeraman     2     1     2
# 2              9.4      9629     Amudhavan Karuppiah     1     1     1
# 3              9.4      9629     Anjana Krishnakumar     1     1     1
# 4              9.4      9629                     Ram     1     1     1
# ..             ...       ...                     ...   ...   ...   ...
# 211            8.0      6743       Toshiyuki Kubooka     3     1     3
# 212            8.0      6552          Keith Maitland     3     1     3
# 213            8.0      6369         Tolga Karaçelik     3     1     3
# 214            8.0      5913      Richard De Aragues     2     1     2
# 215            8.0      5709      Trivikram Srinivas     2     1     2
#
#      AvgRat_Dir
# 0           9.5
# 1           9.5
# 2           9.4
# 3           9.4
# 4           9.4
# ..          ...
# 211         8.0
# 212         8.0
# 213         8.0
# 214         8.0
# 215         8.0
#
# [216 rows x 10 columns]

# %%
#Average rating of movies for the director in (with votingnum  preconditions only)
#>2 Movies re only 24 directors, with 1 we can possibly give chance to...They have credibility to their name


qD = """
SELECT
    movie_id,
    genres,
    numvotes,
    person_id,
    primary_title,
    primary_name AS Director,
    COUNT ( DISTINCT movie_id) AS Movie_Count,
    COUNT (DISTINCT  genres) AS Genre_Count,
    ROUND (AVG(averagerating), 1) as AvgRat
FROM movie_basics
JOIN movie_ratings
    USING (movie_id)
JOIN directors
    USING (movie_id)
JOIN persons
    USING(person_id)
WHERE numvotes >= "5330"
GROUP BY Director
HAVING AvgRat >= 8
ORDER BY AvgRat DESC, Movie_Count DESC

;
"""
Dir_Sql = pd.read_sql(qD,conn)

movieD1_df = pd.DataFrame(Dir_Sql)
movieD1_df
# Out:
#       movie_id                      genres  numvotes  person_id  \
# 0    tt5963218               Drama,History      6509  nm8529623
# 1    tt5963218               Drama,History      6509  nm8359417
# 2    tt7738784                       Drama      9629  nm9988436
# 3    tt7738784                       Drama      9629  nm6041686
# 4    tt7738784                       Drama      9629  nm3591496
# ..         ...                         ...       ...        ...
# 132  tt1698010           Documentary,Sport      5913  nm4003301
# 133  tt1798709        Drama,Romance,Sci-Fi    467232  nm0005069
# 134  tt7961060  Action,Adventure,Animation     16465  nm0619110
# 135  tt1431045     Action,Adventure,Comedy    820847  nm1783265
# 136  tt3560686        Crime,Drama,Thriller      8617  nm4021775
#
#                 primary_title                Director  Movie_Count  \
# 0               Aloko Udapadi  Bharatha Hettiarachchi            1
# 1               Aloko Udapadi        Chathra Weeraman            1
# 2                     Peranbu     Amudhavan Karuppiah            1
# 3                     Peranbu     Anjana Krishnakumar            1
# 4                     Peranbu                     Ram            1
# ..                        ...                     ...          ...
# 132  TT3D: Closer to the Edge      Richard De Aragues            1
# 133                       Her             Spike Jonze            1
# 134  Dragon Ball Super: Broly        Tatsuya Nagamine            1
# 135                  Deadpool              Tim Miller            1
# 136                  The Fool             Yuriy Bykov            1
#
#      Genre_Count  AvgRat
# 0              1     9.5
# 1              1     9.5
# 2              1     9.4
# 3              1     9.4
# 4              1     9.4
# ..           ...     ...
# 132            1     8.0
# 133            1     8.0
# 134            1     8.0
# 135            1     8.0
# 136            1     8.0
#
# [137 rows x 9 columns]

# %%
fig, ax = plt.subplots(ncols = 1, nrows = 1, figsize=(50, 30))
Dir_df.plot.scatter(x = "Director", y = "genres", c = "averagerating" ,s = 150,  colormap = "rainbow",   ax=ax)
ax.set_title('Distribution of Genres by Budget')

# %%
#Keep Table
#Number of Directors in each genre with  preconditions
gD_count = GenDir.groupby("genres").count().sort_values("Director", ascending = False)
gD_count

# %%
#Understanding the number of directors per genre with preconditions
g.sort_value(["movie_id"]).groupby("genres").count()

# %%
#Join director and broken out genre table, only list the top 5 genres from these directors
#How many directors fit under the top 5 genres each - 13
#From the directors which ones have the top 5 genres
#WHERE g.genres in ("Drama","Action", "Comedy", "Thriller", "Documentary")
#Count the number of movies in each genre with preconditions
qdr ="""

SELECT
   g.movie_id,
   g.genres,
   g.primary_title,
   g.averagerating,
   Director,
   Movie_Count,
   Genre_Count,
   AvgRat
FROM g
INNER JOIN movieD1_df AS  mD
    USING (movie_id)

GROUP BY movie_id


;

"""


int1Dir = pysqldf(qdr)
int1Dir

# %% [markdown]
# # Look at Budget- state limitations
# # Use

# %%
#1544 Rows
q = """
SELECT 
   averagerating,
   numvotes,
   movie_id,
   genres,
   Director,
   primary_title
FROM g
JOIN movieD2_df
    USING (movie_id)



;

"""

BudMovie = pysqldf(q)
BudMovie

# %%
#Remove necessary characters from string
Bud_df["production_budget"]=Bud_df["production_budget"].str.strip("&")
Bud_df["production_budget"]=Bud_df["production_budget"].str.replace(",", "")

# %%
#Convert Budget from string to int necessary
Bud_df["production_budget"]=Bud_df["production_budget"].astype(int) 
Bud_df.describe()

# %%
#Joining by names narrowed the list to 638 rows
q = """
SELECT
*
FROM BudMovie AS bm
JOIN Bud_df bd
    ON bm.primary_title = bd.movie
;

"""
bud_join= pysqldf(q)
bud_join.info()

# %%
#Refine the joined budget list.  
#Look to see if the top genres are top and if the same directors for the same movies are still good
q ="""
SELECT
    movie_id,
    movie,
    Director,
    genres,
    averagerating,
    numvotes,
    production_budget AS pbud
FROM bud_join
ORDER BY pbud DESC
;

"""
budget_df= pysqldf(q)
budget_df

# %%
#Formatting Budget https://www.markhneedham.com/blog/2021/04/11/pandas-format-dataframe-numbers-commas-decimals/
#budget_df = budget_df.style.format({
    "pbud": "{:,d}",})

# %%
budget_df.info()

# %%
#Look at average budget for genres

q ="""
SELECT
    movie_id,
    movie,
    Director,
    genres,
    averagerating,
    ROUND (AVG(numvotes), 0) as Avg_Votes,
    pbud,
    ROUND (AVG(pbud), 0) as Avg_Bud
FROM budget_df
GROUP BY genres
ORDER BY Avg_Bud DESC, Avg_Votes DESC
;
"""
budA_df= pysqldf(q)
budA_df

# %%
#Look at top directors (5) Are they on the list

#Drama 86, Biogrpahy 26, Crime 15, Doc and Mystery 10 for representations with under 100 Mill budget
q ="""
SELECT
    movie_id,
    movie,
    Director,
    genres,
    averagerating,
    ROUND (AVG(numvotes), 0) as Avg_Votes,
    pbud,
    COUNT (genres) AS Gen_Count,
    ROUND (AVG(pbud), 0) as Avg_Bud
FROM budget_df
GROUP BY director, genres
HAVING Avg_Bud < 100000000
ORDER BY Gen_Count DESC, Avg_Bud ASC,Avg_Votes DESC 
;
"""
budDir_df= pysqldf(q)
budDir_df

# %%
#Plot the genres by the budget


q ="""
SELECT
    movie_id,
    genres,
    averagerating,
    pbud
FROM budget_df
ORDER BY pbud
;
"""
budGen_df= pysqldf(q)
budGen_df

# %%
#Plot the genres by Budget
fig, ax = plt.subplots(ncols = 1, nrows = 1, figsize=(30, 30))
budGen_df.plot.scatter(x = "genres", y = "pbud" , c = "averagerating" ,s = 150,  colormap = "rainbow",   ax=ax)
ax.set_title('Distribution of Genres by Budget')
